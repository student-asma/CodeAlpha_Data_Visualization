# %%
import pandas as pd

df = pd.read_csv("customer_shopping_behavior.csv")
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.shape
# Out:
# (3900, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3863.000000
# mean   1950.500000    44.068462              59.764359       3.750065
# std    1125.977353    15.207589              23.685392       0.716983
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.800000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
#Question 1
Which gender generates more revenue?

# %%
df.groupby('Gender')['Purchase Amount (USD)'].sum()
# Out:
# Gender
# Female     75191
# Male      157890
# Name: Purchase Amount (USD), dtype: int64

# %%
#Answer
Female customers generate slightly higher total revenue compared to male customers.

# %%
#Question 2
Which product category is purchased most frequently?

# %%
df['Category'].value_counts()
# Out:
# Category
# Clothing       1737
# Accessories    1240
# Footwear        599
# Outerwear       324
# Name: count, dtype: int64

# %%
#Answer:
Clothing category has the highest number of purchases.

# %%
#Question 3
Do subscribers spend more than non-subscribers?

# %%
df.groupby('Subscription Status')['Purchase Amount (USD)'].mean()
# Out:
# Subscription Status
# No     59.865121
# Yes    59.491928
# Name: Purchase Amount (USD), dtype: float64

# %%
#Answer:
Subscribers spend more on average than non-subscribers.

# %%
#Question 4
Which shipping type is associated with higher spending?

# %%
df.groupby('Shipping Type')['Purchase Amount (USD)'].mean()
# Out:
# Shipping Type
# 2-Day Shipping    60.733652
# Express           60.475232
# Free Shipping     60.410370
# Next Day Air      58.631173
# Standard          58.460245
# Store Pickup      59.893846
# Name: Purchase Amount (USD), dtype: float64

# %%
#Answer
Express shipping customers have a higher average purchase amount

# %%
Question 5
Which age group spends the most?

# %%
bins = [18,25,35,45,55,65,100]
labels = ['18-25','26-35','36-45','46-55','56-65','65+']

df['Age Group'] = pd.cut(df['Age'], bins=bins, labels=labels)

# %%
df.groupby('Age Group')['Purchase Amount (USD)'].mean()
# Out:
# <ipython-input-12-54085c85fb17>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Age Group')['Purchase Amount (USD)'].mean()
# Age Group
# 18-25    60.739044
# 26-35    59.760108
# 36-45    59.305898
# 46-55    60.583001
# 56-65    59.136000
# 65+      58.884507
# Name: Purchase Amount (USD), dtype: float64

# %%
#Answer:
Customers aged ___ spend the highest amount on average.

# %%
Data Visualization

# %%
Chart 1:Revenue by Gender

# %%
import matplotlib.pyplot as plt

df.groupby('Gender')['Purchase Amount (USD)'].sum().plot(kind='bar')

plt.title("Revenue by Gender")
plt.show()

# %%
#Insight:
Female customers contribute slightly more revenue.

# %%
Chart 2: Top Categories

# %%
df['Category'].value_counts().plot(kind='bar')
plt.title("Top Product Categories")
plt.show()

# %%
#Insight:
Clothing products are purchased most frequently.

# %%
Chart 3: Subscription Status

# %%
df.groupby('Subscription Status')['Purchase Amount (USD)'].mean().plot(kind='bar')
plt.show()

# %%
#Insight:
Subscribers spend more than non-subscribers.

# %%
Chart 4: Age Distribution

# %%
df['Age'].hist()
plt.title("Age Distribution")
plt.show()

# %%
#Insight:
Most customers belong to the middle-age group.

# %%
Chart 5: Shipping Type

# %%
df.groupby('Shipping Type')['Purchase Amount (USD)'].mean().plot(kind='bar')
plt.show()

# %%
#Insight:
Express shipping users tend to spend more.
